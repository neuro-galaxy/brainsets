# %%
from temporaldata import Data
import h5py

path = "data/processed/schalk_wolpaw_physionet_2009/S002_sess-0.h5"

with h5py.File(path, "r") as f:
    data = Data.from_hdf5(f, lazy=False)

# %%
data.motor_imagery_trials.movements
# Out:
# array(['left_hand', 'rest', 'right_hand', 'rest', 'left_hand', 'rest',
#        'right_hand', 'rest', 'left_hand', 'rest', 'right_hand', 'rest',
#        'right_hand', 'rest', 'left_hand', 'rest', 'right_hand', 'rest',
#        'left_hand', 'rest', 'right_hand', 'rest', 'left_hand', 'rest',
#        'right_hand', 'rest', 'left_hand', 'rest', 'right_hand',
#        'left_hand', 'rest', 'right_hand', 'rest', 'right_hand', 'rest',
#        'left_hand', 'rest', 'right_hand', 'rest', 'left_hand', 'rest',
#        'right_hand', 'rest', 'left_hand', 'rest', 'right_hand', 'rest',
#        'left_hand', 'rest', 'right_hand', 'rest', 'left_hand', 'rest',
#        'left_hand', 'rest', 'right_hand', 'rest', 'left_hand',
#        'left_hand', 'rest', 'right_hand', 'rest', 'right_hand', 'rest',
#        'left_hand', 'rest', 'right_hand', 'rest', 'left_hand', 'rest',
#        'left_hand', 'rest', 'right_hand', 'rest', 'right_hand', 'rest',
# ...

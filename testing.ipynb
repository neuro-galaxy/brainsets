# %%
import h5py
from temporaldata import Data

path = "/home/mila/s/sobralm/brainsets/data/processed/shirazi_hbnr1_ds005505_2024/sub-NDARCA153NKE_task-DiaryOfAWimpyKid.h5"
with h5py.File(path, "r") as f:
    data = Data.from_hdf5(f, lazy=False)

# %%
data.domain.end
# Out:
# array([118.93])

# %%
data.eeg.signal
# Out:
# array([[ 0.00967723,  0.02157276,  0.01527774, ...,  0.19389378,
#         -0.01010095,  0.        ],
#        [ 0.00966109,  0.02155524,  0.01525101, ...,  0.19389378,
#         -0.01011819,  0.        ],
#        [ 0.00964538,  0.0215411 ,  0.01522832, ...,  0.19389378,
#         -0.01013659,  0.        ],
#        ...,
#        [ 0.00978696,  0.02283192,  0.01358592, ...,  0.19389378,
#         -0.00617764,  0.        ],
#        [ 0.00978689,  0.02281252,  0.01357185, ...,  0.19389378,
#         -0.00617931,  0.        ],
#        [ 0.00974878,  0.02280799,  0.01355651, ...,  0.19389378,
#         -0.00619231,  0.        ]], shape=(59466, 129))

# %%
data.channels.id
# Out:
# array(['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11',
#        'E12', 'E13', 'E14', 'E15', 'E16', 'E17', 'E18', 'E19', 'E20',
#        'E21', 'E22', 'E23', 'E24', 'E25', 'E26', 'E27', 'E28', 'E29',
#        'E30', 'E31', 'E32', 'E33', 'E34', 'E35', 'E36', 'E37', 'E38',
#        'E39', 'E40', 'E41', 'E42', 'E43', 'E44', 'E45', 'E46', 'E47',
#        'E48', 'E49', 'E50', 'E51', 'E52', 'E53', 'E54', 'E55', 'E56',
#        'E57', 'E58', 'E59', 'E60', 'E61', 'E62', 'E63', 'E64', 'E65',
#        'E66', 'E67', 'E68', 'E69', 'E70', 'E71', 'E72', 'E73', 'E74',
#        'E75', 'E76', 'E77', 'E78', 'E79', 'E80', 'E81', 'E82', 'E83',
#        'E84', 'E85', 'E86', 'E87', 'E88', 'E89', 'E90', 'E91', 'E92',
#        'E93', 'E94', 'E95', 'E96', 'E97', 'E98', 'E99', 'E100', 'E101',
#        'E102', 'E103', 'E104', 'E105', 'E106', 'E107', 'E108', 'E109',
#        'E110', 'E111', 'E112', 'E113', 'E114', 'E115', 'E116', 'E117',
# ...

# %%
data.channels.types
# Out:
# array(['EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
#        'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG', 'EEG',
# ...
